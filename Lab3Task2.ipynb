# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('D://THINK/Downloads/Modified_Salary_dataset.csv')
print("Dataset:\n", data)
# Out:
# Dataset:
#      Unnamed: 0  YearsExperience  Salary
# 0            0              1.2   39344
# 1            1              1.4   46206
# 2            2              1.6   37732
# 3            3              2.1   43526
# 4            4              2.3   39892
# 5            5              3.0   56643
# 6            6              3.1   60151
# 7            7              3.3   54446
# 8            8              3.3   64446
# 9            9              3.8   57190
# 10          10              4.0   63219
# 11          11              4.1   55795
# 12          12              4.1   56958
# 13          13              4.2   57082
# 14          14              4.6   61112
# 15          15              5.0   67939
# 16          16              5.2   66030
# 17          17              5.4   83089
# 18          18              6.0   81364
# 19          19              6.1   93941
# 20          20              6.9   91739
# 21          21              7.2   98274
# 22          22              8.0  101303
# 23          23              8.3  113813
# 24          24              8.8  109432
# 25          25              9.1  105583
# 26          26              9.6  116970
# 27          27              9.7  112636
# 28          28             10.4  122392
# 29          29             10.6  121873
# 30          30              1.5  150000

# %%
X = data[['YearsExperience']]
Y = data['Salary']

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
predicted_score = model.predict([[6]])
print("Predicted score for 6 years of experience:", predicted_score[0])
# Out:
# Predicted score for 6 years of experience: 83921.55841976618
# D:\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 7757.842127273813
# Intercept: 37374.5056561233

# %%
Y_pred = model.predict(X)
print("Mean Squared Error:", mean_squared_error(Y, Y_pred))
# Out:
# Mean Squared Error: 391791615.4249493

# %%
plt.scatter(X, Y, color='green', label='Actual Data')
plt.plot(X, model.predict(X), color='blue', label='Regression Line')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Years Experience vs Salary')
plt.legend()
plt.show()
